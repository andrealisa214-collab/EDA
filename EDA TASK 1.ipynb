# %%
import pandas as pd
df=pd.read_json("financial_practice_25_records.json")
df
# Out:
#     Transaction_ID       Date Customer   Product     Category  Quantity  \
# 0             1001 2026-01-01      Anu    Laptop  Electronics         2
# 1             1002 2026-01-02    Rahul    Mobile  Electronics         1
# 2             1003 2026-01-03    Meena    Tablet  Electronics         3
# 3             1004 2026-01-04    Arjun   Monitor  Electronics         2
# 4             1005 2026-01-05    Priya  Keyboard  Accessories         5
# 5             1006 2026-01-06   Vishnu     Mouse  Accessories         4
# 6             1007 2026-01-07     Neha   Printer       Office         1
# 7             1008 2026-01-08    Akhil    Laptop  Electronics         1
# 8             1009 2026-01-09    Sneha    Mobile  Electronics         2
# 9             1010 2026-01-10    Rohan    Tablet  Electronics         3
# 10            1011 2026-01-11     Diya   Monitor  Electronics         2
# 11            1012 2026-01-12    Kiran  Keyboard  Accessories         6
# ...

# %%
df.head()
# Out:
#    Transaction_ID       Date Customer   Product     Category  Quantity  \
# 0            1001 2026-01-01      Anu    Laptop  Electronics         2
# 1            1002 2026-01-02    Rahul    Mobile  Electronics         1
# 2            1003 2026-01-03    Meena    Tablet  Electronics         3
# 3            1004 2026-01-04    Arjun   Monitor  Electronics         2
# 4            1005 2026-01-05    Priya  Keyboard  Accessories         5
#
#    Sales_Amount  Profit Payment_Mode
# 0         90000   12000          UPI
# 1         35000    5000         Card
# 2         45000    7000         Cash
# 3         30000    4500          UPI
# 4          7500    1500         Card

# %%
df.tail()
# Out:
#     Transaction_ID       Date Customer  Product     Category  Quantity  \
# 20            1021 2026-01-21    Divya  Printer       Office         2
# 21            1022 2026-01-22    Vivek   Laptop  Electronics         1
# 22            1023 2026-01-23   Reshma   Mobile  Electronics         2
# 23            1024 2026-01-24     Hari   Tablet  Electronics         3
# 24            1025 2026-01-25     Amal  Monitor  Electronics         2
#
#     Sales_Amount  Profit Payment_Mode
# 20         20000    3200          UPI
# 21         70000   10000         Card
# 22         34000    5200         Cash
# 23         46000    7000          UPI
# 24         29000    4300         Card

# %%
df.isnull().sum()
# Out:
# Transaction_ID    0
# Date              0
# Customer          0
# Product           0
# Category          0
# Quantity          0
# Sales_Amount      0
# Profit            0
# Payment_Mode      0
# dtype: int64

# %%
df["Profit"]=df["Profit"].ffill()

# %%
df["Sales_Amount"]=df["Sales_Amount"].bfill()

# %%
df["Quantity"]=df["Quantity"].ffill()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Profit"].mean()
df["Profit"].median()
df["Profit"].mode()
# Out:
# 0    7000
# Name: Profit, dtype: int64

# %%
df
# Out:
#     Transaction_ID       Date Customer   Product     Category  Quantity  \
# 0             1001 2026-01-01      Anu    Laptop  Electronics         2
# 1             1002 2026-01-02    Rahul    Mobile  Electronics         1
# 2             1003 2026-01-03    Meena    Tablet  Electronics         3
# 3             1004 2026-01-04    Arjun   Monitor  Electronics         2
# 4             1005 2026-01-05    Priya  Keyboard  Accessories         5
# 5             1006 2026-01-06   Vishnu     Mouse  Accessories         4
# 6             1007 2026-01-07     Neha   Printer       Office         1
# 7             1008 2026-01-08    Akhil    Laptop  Electronics         1
# 8             1009 2026-01-09    Sneha    Mobile  Electronics         2
# 9             1010 2026-01-10    Rohan    Tablet  Electronics         3
# 10            1011 2026-01-11     Diya   Monitor  Electronics         2
# 11            1012 2026-01-12    Kiran  Keyboard  Accessories         6
# ...

# %%
df["Sales_Amount"].mean()
df["Sales_Amount"].median()
df["Sales_Amount"].mode()
# Out:
# 0      4000
# 1      4500
# 2      5000
# 3      7500
# 4      8000
# 5      9000
# 6     18000
# 7     20000
# 8     22000
# 9     28000
# 10    29000
# 11    30000
# 12    32000
# 13    34000
# 14    35000
# 15    36000
# 16    38000
# 17    42000
# 18    45000
# 19    46000
# 20    48000
# 21    55000
# 22    60000
# 23    70000
# 24    90000
# Name: Sales_Amount, dtype: int64

# %%
df
# Out:
#     Transaction_ID       Date Customer   Product     Category  Quantity  \
# 0             1001 2026-01-01      Anu    Laptop  Electronics         2
# 1             1002 2026-01-02    Rahul    Mobile  Electronics         1
# 2             1003 2026-01-03    Meena    Tablet  Electronics         3
# 3             1004 2026-01-04    Arjun   Monitor  Electronics         2
# 4             1005 2026-01-05    Priya  Keyboard  Accessories         5
# 5             1006 2026-01-06   Vishnu     Mouse  Accessories         4
# 6             1007 2026-01-07     Neha   Printer       Office         1
# 7             1008 2026-01-08    Akhil    Laptop  Electronics         1
# 8             1009 2026-01-09    Sneha    Mobile  Electronics         2
# 9             1010 2026-01-10    Rohan    Tablet  Electronics         3
# 10            1011 2026-01-11     Diya   Monitor  Electronics         2
# 11            1012 2026-01-12    Kiran  Keyboard  Accessories         6
# ...

# %%
df["Quantity"].mean()
df["Quantity"].median()
df["Quantity"].mode()
# Out:
# 0    2
# Name: Quantity, dtype: int64

# %%
df
# Out:
#     Transaction_ID       Date Customer   Product     Category  Quantity  \
# 0             1001 2026-01-01      Anu    Laptop  Electronics         2
# 1             1002 2026-01-02    Rahul    Mobile  Electronics         1
# 2             1003 2026-01-03    Meena    Tablet  Electronics         3
# 3             1004 2026-01-04    Arjun   Monitor  Electronics         2
# 4             1005 2026-01-05    Priya  Keyboard  Accessories         5
# 5             1006 2026-01-06   Vishnu     Mouse  Accessories         4
# 6             1007 2026-01-07     Neha   Printer       Office         1
# 7             1008 2026-01-08    Akhil    Laptop  Electronics         1
# 8             1009 2026-01-09    Sneha    Mobile  Electronics         2
# 9             1010 2026-01-10    Rohan    Tablet  Electronics         3
# 10            1011 2026-01-11     Diya   Monitor  Electronics         2
# 11            1012 2026-01-12    Kiran  Keyboard  Accessories         6
# ...

# %%
df["Category"]=df["Category"].str.strip().str.title()
